# %% [markdown]
# Task 2: Create a Personalized Greeting Problem Statement: Write a Python program that:
#
# Takes a user's first name and last name as input.
# Concatenates the first name and last name into a full name.
# Prints a personalized greeting message using the full name.

# %%
"""We will start with assigning the input() function to the variables."""

first_name=input("Enter your first name:")
last_name=input("Enter your last name:")

full_name=first_name+ ' ' + last_name  #concates

print('Hello,',full_name,'!', 'Welcome to the Python program.')
# Out:
# Enter your first name:Albert
# Enter your last name:Einstein
# Hello, Albert Einstein ! Welcome to the Python program.
